# %%
import pandas as pd
from tabulate import tabulate
import numpy as np
# Out:
# /var/folders/9x/00rwcm8x4897s1m2h7wcc84h0000gn/T/ipykernel_968/4130189644.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
curr_folder = 'syn2'
data_folder = '/Users/eugenegan/Documents/cs4220_projects/data'

# %%
df_label = pd.read_csv(f'{data_folder}/{curr_folder}/{curr_folder}_truth.bed', delimiter='\t')
df_label
# Out:
#       1    1787808  1787808.1
# 0     1    1819379    1819379
# 1     1    2115269    2115269
# 2     1    2422541    2422541
# 3     1    2494323    2494323
# 4     1    3106502    3106502
# ...  ..        ...        ...
# 4326  X  153631641  153631641
# 4327  X  154104082  154104082
# 4328  X  154417237  154417237
# 4329  X  154795622  154795622
# 4330  X  155068256  155068256
#
# [4331 rows x 3 columns]

# %%
df1 = pd.read_csv(f'{data_folder}/{curr_folder}/snv-parse-{curr_folder}_all_features.txt', delimiter='\t')
# df1 = pd.read_csv(f'{data_folder}/original-{curr_folder}-parse.txt', delimiter='\t')
df_label = pd.read_csv(f'{data_folder}/{curr_folder}/{curr_folder}_truth.bed', delimiter='\t',
names=['Chr', 'START_POS_REF', 'END_POS_REF'])
df1['Chr'] = df1['Chr'].astype(str)
df_label['Chr'] = df_label['Chr'].astype(str)
df_joined = df1.merge(df_label, on=['Chr', 'START_POS_REF', 'END_POS_REF'], how='outer', indicator=True)
df_joined[df_joined['_merge'] == 'right_only']
# Out:
# /var/folders/9x/00rwcm8x4897s1m2h7wcc84h0000gn/T/ipykernel_968/1065868294.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv(f'{data_folder}/{curr_folder}/snv-parse-{curr_folder}_all_features.txt', delimiter='\t')
#       Chr  START_POS_REF  END_POS_REF  REF  ALT REF_MFVdVs ALT_MFVdVs  \
# 1484    1      108951682    108951682  NaN  NaN        NaN        NaN
# 2570    1      161625374    161625374  NaN  NaN        NaN        NaN
# 4248   10       42511865     42511865  NaN  NaN        NaN        NaN
# 4482   10       47193330     47193330  NaN  NaN        NaN        NaN
# 4511   10       48003623     48003623  NaN  NaN        NaN        NaN
# 5217   10      111002443    111002443  NaN  NaN        NaN        NaN
# 6164   11       38008306     38008306  NaN  NaN        NaN        NaN
# 6604   11       62158661     62158661  NaN  NaN        NaN        NaN
# 9271   13       25602981     25602981  NaN  NaN        NaN        NaN
# 9640   13       56120064     56120064  NaN  NaN        NaN        NaN
# 9658   13       58565812     58565812  NaN  NaN        NaN        NaN
# 11829  15       23450550     23450550  NaN  NaN        NaN        NaN
# 19538   2      110504640    110504640  NaN  NaN        NaN        NaN
# 23694  22       17175646     17175646  NaN  NaN        NaN        NaN
# 24515   3       21711775     21711775  NaN  NaN        NaN        NaN
# 25661   3      117904072    117904072  NaN  NaN        NaN        NaN
# 26323   3      180571138    180571138  NaN  NaN        NaN        NaN
# 27872   4       73687566     73687566  NaN  NaN        NaN        NaN
# 30322   5       70178029     70178029  NaN  NaN        NaN        NaN
# 32153   6       40168576     40168576  NaN  NaN        NaN        NaN
# 32154   6       40169832     40169832  NaN  NaN        NaN        NaN
# 32260   6       50579827     50579827  NaN  NaN        NaN        NaN
# 35227   7       74662382     74662382  NaN  NaN        NaN        NaN
# 37360   8       67250214     67250214  NaN  NaN        NaN        NaN
# 38809   9       41439476     41439476  NaN  NaN        NaN        NaN
# 38846   9       42835762     42835762  NaN  NaN        NaN        NaN
# 39550   9       69371557     69371557  NaN  NaN        NaN        NaN
# 43637   X       70920198     70920198  NaN  NaN        NaN        NaN
# 43648   X       72109551     72109551  NaN  NaN        NaN        NaN
#
#       Sample_Name FILTER_Mutect2 FILTER_Freebayes  ... vs_SPV vs_SSC  vd_AF  \
# 1484          NaN            NaN              NaN  ...    NaN    NaN    NaN
# 2570          NaN            NaN              NaN  ...    NaN    NaN    NaN
# 4248          NaN            NaN              NaN  ...    NaN    NaN    NaN
# 4482          NaN            NaN              NaN  ...    NaN    NaN    NaN
# 4511          NaN            NaN              NaN  ...    NaN    NaN    NaN
# 5217          NaN            NaN              NaN  ...    NaN    NaN    NaN
# 6164          NaN            NaN              NaN  ...    NaN    NaN    NaN
# 6604          NaN            NaN              NaN  ...    NaN    NaN    NaN
# 9271          NaN            NaN              NaN  ...    NaN    NaN    NaN
# 9640          NaN            NaN              NaN  ...    NaN    NaN    NaN
# 9658          NaN            NaN              NaN  ...    NaN    NaN    NaN
# 11829         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 19538         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 23694         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 24515         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 25661         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 26323         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 27872         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 30322         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 32153         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 32154         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 32260         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 35227         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 37360         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 38809         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 38846         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 39550         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 43637         NaN            NaN              NaN  ...    NaN    NaN    NaN
# 43648         NaN            NaN              NaN  ...    NaN    NaN    NaN
#
#        vd_DP  vd_MSI  vd_SAMPLE  vd_SOR  vd_SSF  vd_VD      _merge
# 1484     NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 2570     NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 4248     NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 4482     NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 4511     NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 5217     NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 6164     NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 6604     NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 9271     NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 9640     NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 9658     NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 11829    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 19538    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 23694    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 24515    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 25661    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 26323    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 27872    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 30322    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 32153    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 32154    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 32260    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 35227    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 37360    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 38809    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 38846    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 39550    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 43637    NaN     NaN        NaN     NaN     NaN    NaN  right_only
# 43648    NaN     NaN        NaN     NaN     NaN    NaN  right_only
#
# [29 rows x 56 columns]

# %%
df_joined[df_joined['_merge'] == 'right_only'].shape
# Out:
# (29, 56)

# %%
m2_cols = [col.split('_', 1)[1] for col in df_joined.columns if col.startswith('m2_')]
f_cols = [col.split('_', 1)[1] for col in df_joined.columns if col.startswith('f_')]
vs_cols = [col.split('_', 1)[1] for col in df_joined.columns if col.startswith('vs_')]
vd_cols = [col.split('_', 1)[1] for col in df_joined.columns if col.startswith('vd_')]
print(f"Mutect2 features: {m2_cols}")
print(f"Freebayes features: {f_cols}")
print(f"Varscan features: {vs_cols}")
print(f"Vardict features: {vd_cols}")
# Out:
# Mutect2 features: ['MQ', 'FS', 'MQ0', 'MQRankSum', 'NLOD', 'PON']
# Freebayes features: ['MQMR', 'MQM', 'AB', 'ABP', 'AC', 'AF', 'AN', 'AO', 'GTI', 'LEN', 'MEANALT', 'MIN_DP', 'NS', 'NUMALT', 'ODDS', 'PAIRED', 'PAIREDR', 'PAO', 'PQA', 'PQR', 'PRO', 'QA', 'QR', 'RO', 'RPL', 'RPP']
# Varscan features: ['DP', 'GPV', 'SPV', 'SSC']
# Vardict features: ['AF', 'DP', 'MSI', 'SAMPLE', 'SOR', 'SSF', 'VD']

# %%
df_joined_right_only = df_joined[df_joined['_merge'] == 'right_only']
df_joined_right_only['Missed_pos'] = df_joined_right_only['Chr'].astype(str) + '_' + df_joined_right_only['START_POS_REF'].astype(str)
missed_pos = df_joined_right_only['Missed_pos'].unique()
df_joined_right_only.drop(['Missed_pos'], axis=1, inplace=True)
missed_pos
# Out:
# /var/folders/9x/00rwcm8x4897s1m2h7wcc84h0000gn/T/ipykernel_968/3588080496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_joined_right_only['Missed_pos'] = df_joined_right_only['Chr'].astype(str) + '_' + df_joined_right_only['START_POS_REF'].astype(str)
# /var/folders/9x/00rwcm8x4897s1m2h7wcc84h0000gn/T/ipykernel_968/3588080496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_joined_right_only.drop(['Missed_pos'], axis=1, inplace=True)
# array(['1_108951682', '1_161625374', '10_42511865', '10_47193330',
#        '10_48003623', '10_111002443', '11_38008306', '11_62158661',
#        '13_25602981', '13_56120064', '13_58565812', '15_23450550',
#        '2_110504640', '22_17175646', '3_21711775', '3_117904072',
#        '3_180571138', '4_73687566', '5_70178029', '6_40168576',
#        '6_40169832', '6_50579827', '7_74662382', '8_67250214',
#        '9_41439476', '9_42835762', '9_69371557', 'X_70920198',
#        'X_72109551'], dtype=object)

# %%
df_missed = pd.DataFrame(columns=df_joined.columns)
# df_missed.columns
algo_name_list = ['mutect2', 'varscan', 'vardict', 'freebayes']
sample_name = df_joined['Sample_Name'].unique()[0]
for chr_pos in missed_pos:
    print(f"Processing {chr_pos}")
    chr = chr_pos.split('_')[0]
    pos = chr_pos.split('_')[1]

    m2_ref = None
    m2_alt = None
    f_ref = None
    f_alt = None
    vd_ref = None
    vd_alt = None
    vs_ref = None
    vs_alt = None

    curr_row = {}
    curr_row['Chr'] = chr
    curr_row['START_POS_REF'] = pos
    curr_row['END_POS_REF'] = pos
    curr_row['FILTER_Mutect2'] = False
    curr_row['FILTER_Freebayes'] = False
    curr_row['FILTER_Vardict'] = False
    curr_row['FILTER_Varscan'] = False

    curr_row['Sample_Name'] = sample_name
    for algo_name in algo_name_list:
        print(algo_name)
        if algo_name == 'mutect2':
            algo_features = m2_cols
            prefix = 'm2_'
        elif algo_name == 'varscan':
            algo_features = vs_cols
            prefix = 'vs_'
        elif  algo_name == 'vardict':
            algo_features = vd_cols
            prefix = 'vd_'
        elif algo_name == 'freebayes':
            algo_features = f_cols
            prefix = 'f_'
        with open('{}/{}/{}-{}.vcf'.format(data_folder, curr_folder, curr_folder, algo_name), 'r') as f:
            lines = [line.rstrip() for line in f if line.startswith(f'{chr}\t{pos}\t')]
            if len(lines) == 1:
                m2_ref = 'NA'
                m2_alt = 'NA'
                f_ref = 'NA'
                f_alt = 'NA'
                vd_ref = 'NA'
                vd_alt = 'NA'
                vs_ref = 'NA'
                vs_alt = 'NA'

                line = lines[0]
                cols = line.split('\t')
                if algo_name == 'mutect2':
                    m2_ref = cols[3]
                    m2_alt = cols[4]
                elif algo_name == 'varscan':
                    vs_ref = cols[3]
                    vs_alt = cols[4]
                elif  algo_name == 'vardict':
                    vd_ref = cols[3]
                    vd_alt = cols[4]
                elif algo_name == 'freebayes':
                    f_ref = cols[3]
                    f_alt = cols[4]
                
                info = cols[7]
                feature_list = info.split(';')
                for feature in feature_list:

                    if len(feature.split('=')) == 1:
                        feature_name = feature.split('=')[0]
                        feature_val = None
                    else:
                        feature_name = feature.split('=')[0]
                        feature_val = feature.split('=')[1]
                    if feature_name in algo_features:
                        curr_row[prefix + feature_name] = feature_val
            elif len(lines) > 1:
                input("Unexpected: algo contains more than 1 entry for 1 position")
            else:
                for feature_name in algo_features:
                    curr_row[prefix + feature_name] = None
    
    # None of the 4 algos pick up this
    if m2_ref is None:
        continue

    for i in [m2_ref, f_ref, vd_ref, vs_ref]:
        if i != 'NA':
            curr_row['REF'] = i
            break
    for i in [m2_alt, f_alt, vd_alt, vs_alt]:
        if i != 'NA':
            curr_row['ALT'] = i
            break
    curr_row['REF_MFVdVs'] = f'{m2_ref}/{f_ref}/{vd_ref}/{vs_ref}/'
    curr_row['ALT_MFVdVs'] = f'{m2_alt}/{f_alt}/{vd_alt}/{vs_alt}/'
    curr_row['_merge'] = 'right_only'

    for col in df_missed.columns:
        if col not in curr_row.keys():
            print(f'missed col: {col}')
            curr_row[col] = None
        
    df_missed = df_missed._append(curr_row, ignore_index = True) 
    print(tabulate(df_missed, headers='keys', tablefmt='psql'))
# Out:
# Processing 1_108951682
# mutect2
# varscan
# vardict
# freebayes
# Processing 1_161625374
# mutect2
# varscan
# vardict
# freebayes
# Processing 10_42511865
# mutect2
# varscan
# vardict
# freebayes
# +----+-------+-----------------+---------------+-------+-------+--------------+--------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+--------+---------+--------+--------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+----------+----------+---------+------------+
# |    |   Chr |   START_POS_REF |   END_POS_REF | REF   | ALT   | REF_MFVdVs   | ALT_MFVdVs   | Sample_Name   | FILTER_Mutect2   | FILTER_Freebayes   | FILTER_Vardict   | FILTER_Varscan   | m2_MQ   | m2_FS   | m2_MQ0   | m2_MQRankSum   | m2_NLOD   | m2_PON   | f_MQMR   | f_MQM   | f_AB   | f_ABP   | f_AC   | f_AF   | f_AN   | f_AO   | f_GTI   | f_LEN   | f_MEANALT   | f_MIN_DP   | f_NS   | f_NUMALT   | f_ODDS   | f_PAIRED   | f_PAIREDR   | f_PAO   | f_PQA   | f_PQR   | f_PRO   | f_QA   | f_QR   | f_RO   | f_RPL   | f_RPP   |   vs_DP |   vs_GPV |     vs_SPV |   vs_SSC | vd_AF   | vd_DP   | vd_MSI   | vd_SAMPLE   | vd_SOR   | vd_SSF   | vd_VD   | _merge     |
# |----+-------+-----------------+---------------+-------+-------+--------------+--------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+--------+---------+--------+--------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+----------+----------+---------+------------|
# |  0 |    10 |        42511865 |      42511865 | T     | C     | NA/NA/NA/T/  | NA/NA/NA/C/  | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |        |         |        |        |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |      58 |        1 | 0.00016168 |       37 |         |         |          |             |          |          |         | right_only |
# +----+-------+-----------------+---------------+-------+-------+--------------+--------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+--------+---------+--------+--------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+----------+----------+---------+------------+
# Processing 10_47193330
# mutect2
# varscan
# vardict
# freebayes
# Processing 10_48003623
# mutect2
# varscan
# vardict
# freebayes
# missed col: m2_PON
# +----+-------+-----------------+---------------+-------+-------+--------------+--------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+--------+---------+--------+--------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+----------+----------+---------+------------+
# |    |   Chr |   START_POS_REF |   END_POS_REF | REF   | ALT   | REF_MFVdVs   | ALT_MFVdVs   | Sample_Name   | FILTER_Mutect2   | FILTER_Freebayes   | FILTER_Vardict   | FILTER_Varscan   |   m2_MQ |   m2_FS |   m2_MQ0 |   m2_MQRankSum |   m2_NLOD | m2_PON   | f_MQMR   | f_MQM   | f_AB   | f_ABP   | f_AC   | f_AF   | f_AN   | f_AO   | f_GTI   | f_LEN   | f_MEANALT   | f_MIN_DP   | f_NS   | f_NUMALT   | f_ODDS   | f_PAIRED   | f_PAIREDR   | f_PAO   | f_PQA   | f_PQR   | f_PRO   | f_QA   | f_QR   | f_RO   | f_RPL   | f_RPP   |   vs_DP |   vs_GPV |     vs_SPV |   vs_SSC |   vd_AF |   vd_DP |   vd_MSI | vd_SAMPLE   |   vd_SOR |   vd_SSF |   vd_VD | _merge     |
# |----+-------+-----------------+---------------+-------+-------+--------------+--------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+--------+---------+--------+--------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+----------+----------+---------+------------|
# |  0 |    10 |        42511865 |      42511865 | T     | C     | NA/NA/NA/T/  | NA/NA/NA/C/  | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |        |         |        |        |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |      58 |        1 | 0.00016168 |       37 |         |         |          |             |          |          |         | right_only |
# |  1 |    10 |        48003623 |      48003623 | A     | C     | NA/NA/A/NA/  | NA/NA/C/NA/  | dream2-T      | False            | False              | False            | False            |   39.84 |   3.067 |       14 |         -2.051 |      2.11 |          |          |         |        |         |        |        |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |         |          |            |          |    0.25 |       8 |        2 | dream2-T    |      inf |  0.30769 |       2 | right_only |
# +----+-------+-----------------+---------------+-------+-------+--------------+--------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+--------+---------+--------+--------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+----------+----------+---------+------------+
# Processing 10_111002443
# mutect2
# varscan
# vardict
# freebayes
# Processing 11_38008306
# mutect2
# varscan
# vardict
# freebayes
# +----+-------+-----------------+---------------+--------+-------+------------------+--------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+--------+---------+--------+--------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------+
# |    |   Chr |   START_POS_REF |   END_POS_REF | REF    | ALT   | REF_MFVdVs       | ALT_MFVdVs   | Sample_Name   | FILTER_Mutect2   | FILTER_Freebayes   | FILTER_Vardict   | FILTER_Varscan   |   m2_MQ |   m2_FS |   m2_MQ0 |   m2_MQRankSum |   m2_NLOD | m2_PON   | f_MQMR   | f_MQM   | f_AB   | f_ABP   | f_AC   | f_AF   | f_AN   | f_AO   | f_GTI   | f_LEN   | f_MEANALT   | f_MIN_DP   | f_NS   | f_NUMALT   | f_ODDS   | f_PAIRED   | f_PAIREDR   | f_PAO   | f_PQA   | f_PQR   | f_PRO   | f_QA   | f_QR   | f_RO   | f_RPL   | f_RPP   |   vs_DP |   vs_GPV |     vs_SPV |   vs_SSC |   vd_AF |   vd_DP |   vd_MSI | vd_SAMPLE   |    vd_SOR |   vd_SSF |   vd_VD | _merge     |
# |----+-------+-----------------+---------------+--------+-------+------------------+--------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+--------+---------+--------+--------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------|
# |  0 |    10 |        42511865 |      42511865 | T      | C     | NA/NA/NA/T/      | NA/NA/NA/C/  | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |        |         |        |        |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |      58 | 1        | 0.00016168 |       37 |         |         |          |             |           |          |         | right_only |
# |  1 |    10 |        48003623 |      48003623 | A      | C     | NA/NA/A/NA/      | NA/NA/C/NA/  | dream2-T      | False            | False              | False            | False            |   39.84 |   3.067 |       14 |         -2.051 |      2.11 |          |          |         |        |         |        |        |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |         |          |            |          |    0.25 |       8 |        2 | dream2-T    | inf       |  0.30769 |       2 | right_only |
# |  2 |    11 |        38008306 |      38008306 | GAAGAA | G     | NA/NA/GAAGAA/NA/ | NA/NA/G/NA/  | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |        |         |        |        |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |      45 | 5.85e-16 | 0.82113    |        0 |    0.5  |      34 |        5 | dream2-T    |   0.19025 |  0.00307 |      17 | right_only |
# +----+-------+-----------------+---------------+--------+-------+------------------+--------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+--------+---------+--------+--------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------+
# Processing 11_62158661
# mutect2
# varscan
# vardict
# freebayes
# missed col: f_MQMR
# missed col: f_MQM
# missed col: f_AB
# missed col: f_ABP
# missed col: f_AO
# missed col: f_GTI
# missed col: f_MEANALT
# missed col: f_MIN_DP
# missed col: f_NUMALT
# missed col: f_ODDS
# missed col: f_PAIRED
# missed col: f_PAIREDR
# missed col: f_PAO
# missed col: f_PQA
# missed col: f_PQR
# missed col: f_PRO
# missed col: f_QA
# missed col: f_QR
# missed col: f_RO
# missed col: f_RPL
# missed col: f_RPP
# +----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+--------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------+
# |    |   Chr |   START_POS_REF |   END_POS_REF | REF    | ALT   | REF_MFVdVs       | ALT_MFVdVs    | Sample_Name   | FILTER_Mutect2   | FILTER_Freebayes   | FILTER_Vardict   | FILTER_Varscan   |   m2_MQ |   m2_FS |   m2_MQ0 |   m2_MQRankSum |   m2_NLOD | m2_PON   | f_MQMR   | f_MQM   | f_AB   | f_ABP   | f_AC   | f_AF      |   f_AN | f_AO   | f_GTI   | f_LEN   | f_MEANALT   | f_MIN_DP   |   f_NS | f_NUMALT   | f_ODDS   | f_PAIRED   | f_PAIREDR   | f_PAO   | f_PQA   | f_PQR   | f_PRO   | f_QA   | f_QR   | f_RO   | f_RPL   | f_RPP   |   vs_DP |   vs_GPV |     vs_SPV |   vs_SSC |   vd_AF |   vd_DP |   vd_MSI | vd_SAMPLE   |    vd_SOR |   vd_SSF |   vd_VD | _merge     |
# |----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+--------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------|
# |  0 |    10 |        42511865 |      42511865 | T      | C     | NA/NA/NA/T/      | NA/NA/NA/C/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |        |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |      58 | 1        | 0.00016168 |       37 |         |         |          |             |           |          |         | right_only |
# |  1 |    10 |        48003623 |      48003623 | A      | C     | NA/NA/A/NA/      | NA/NA/C/NA/   | dream2-T      | False            | False              | False            | False            |   39.84 |   3.067 |       14 |         -2.051 |      2.11 |          |          |         |        |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |         |          |            |          |  0.25   |       8 |        2 | dream2-T    | inf       |  0.30769 |       2 | right_only |
# |  2 |    11 |        38008306 |      38008306 | GAAGAA | G     | NA/NA/GAAGAA/NA/ | NA/NA/G/NA/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |        |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |      45 | 5.85e-16 | 0.82113    |        0 |  0.5    |      34 |        5 | dream2-T    |   0.19025 |  0.00307 |      17 | right_only |
# |  3 |    11 |        62158661 |      62158661 | G      | A,T   | NA/G/NA/NA/      | NA/A,T/NA/NA/ | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |        |         | 3,1    | 0.75,0.25 |      4 |        |         | 1,1     |             |            |      2 |            |          |            |             |         |         |         |         |        |        |        |         |         |     104 | 0        | 1          |        0 |  0.6735 |      49 |        3 | dream2-T    |   0       |  0       |      33 | right_only |
# +----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+--------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------+
# Processing 13_25602981
# mutect2
# varscan
# vardict
# freebayes
# missed col: m2_PON
# +----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+--------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------+
# |    |   Chr |   START_POS_REF |   END_POS_REF | REF    | ALT   | REF_MFVdVs       | ALT_MFVdVs    | Sample_Name   | FILTER_Mutect2   | FILTER_Freebayes   | FILTER_Vardict   | FILTER_Varscan   |   m2_MQ |   m2_FS |   m2_MQ0 |   m2_MQRankSum |   m2_NLOD | m2_PON   | f_MQMR   | f_MQM   | f_AB   | f_ABP   | f_AC   | f_AF      |   f_AN | f_AO   | f_GTI   | f_LEN   | f_MEANALT   | f_MIN_DP   |   f_NS | f_NUMALT   | f_ODDS   | f_PAIRED   | f_PAIREDR   | f_PAO   | f_PQA   | f_PQR   | f_PRO   | f_QA   | f_QR   | f_RO   | f_RPL   | f_RPP   |   vs_DP |   vs_GPV |     vs_SPV |   vs_SSC |   vd_AF |   vd_DP |   vd_MSI | vd_SAMPLE   |    vd_SOR |   vd_SSF |   vd_VD | _merge     |
# |----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+--------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------|
# |  0 |    10 |        42511865 |      42511865 | T      | C     | NA/NA/NA/T/      | NA/NA/NA/C/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |        |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |      58 | 1        | 0.00016168 |       37 |         |         |          |             |           |          |         | right_only |
# |  1 |    10 |        48003623 |      48003623 | A      | C     | NA/NA/A/NA/      | NA/NA/C/NA/   | dream2-T      | False            | False              | False            | False            |   39.84 |   3.067 |       14 |         -2.051 |      2.11 |          |          |         |        |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |         |          |            |          |  0.25   |       8 |        2 | dream2-T    | inf       |  0.30769 |       2 | right_only |
# |  2 |    11 |        38008306 |      38008306 | GAAGAA | G     | NA/NA/GAAGAA/NA/ | NA/NA/G/NA/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |        |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |      45 | 5.85e-16 | 0.82113    |        0 |  0.5    |      34 |        5 | dream2-T    |   0.19025 |  0.00307 |      17 | right_only |
# |  3 |    11 |        62158661 |      62158661 | G      | A,T   | NA/G/NA/NA/      | NA/A,T/NA/NA/ | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |        |         | 3,1    | 0.75,0.25 |      4 |        |         | 1,1     |             |            |      2 |            |          |            |             |         |         |         |         |        |        |        |         |         |     104 | 0        | 1          |        0 |  0.6735 |      49 |        3 | dream2-T    |   0       |  0       |      33 | right_only |
# |  4 |    13 |        25602981 |      25602981 | T      | A     | NA/NA/T/NA/      | NA/NA/A/NA/   | dream2-T      | False            | False              | False            | False            |   52.16 |   0     |        3 |         -2.868 |      3.61 |          |          |         |        |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |         |          |            |          |  0.1818 |      11 |        2 | dream2-T    | inf       |  0.21739 |       2 | right_only |
# +----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+--------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------+
# Processing 13_56120064
# mutect2
# varscan
# vardict
# freebayes
# Processing 13_58565812
# mutect2
# varscan
# vardict
# freebayes
# Processing 15_23450550
# mutect2
# varscan
# vardict
# freebayes
# Processing 2_110504640
# mutect2
# varscan
# vardict
# freebayes
# Processing 22_17175646
# mutect2
# varscan
# vardict
# freebayes
# Processing 3_21711775
# mutect2
# varscan
# vardict
# freebayes
# Processing 3_117904072
# mutect2
# varscan
# vardict
# freebayes
# missed col: f_MIN_DP
# +----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+----------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------+
# |    |   Chr |   START_POS_REF |   END_POS_REF | REF    | ALT   | REF_MFVdVs       | ALT_MFVdVs    | Sample_Name   | FILTER_Mutect2   | FILTER_Freebayes   | FILTER_Vardict   | FILTER_Varscan   |   m2_MQ |   m2_FS |   m2_MQ0 |   m2_MQRankSum |   m2_NLOD | m2_PON   |   f_MQMR |   f_MQM |     f_AB |   f_ABP | f_AC   | f_AF      |   f_AN |   f_AO |   f_GTI | f_LEN   |   f_MEANALT | f_MIN_DP   |   f_NS |   f_NUMALT |   f_ODDS |   f_PAIRED |   f_PAIREDR |   f_PAO |   f_PQA |   f_PQR |   f_PRO |   f_QA |   f_QR |   f_RO |   f_RPL |   f_RPP |   vs_DP |   vs_GPV |     vs_SPV |   vs_SSC |   vd_AF |   vd_DP |   vd_MSI | vd_SAMPLE   |    vd_SOR |   vd_SSF |   vd_VD | _merge     |
# |----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+----------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------|
# |  0 |    10 |        42511865 |      42511865 | T      | C     | NA/NA/NA/T/      | NA/NA/NA/C/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |      58 | 1        | 0.00016168 |       37 |         |         |          |             |           |          |         | right_only |
# |  1 |    10 |        48003623 |      48003623 | A      | C     | NA/NA/A/NA/      | NA/NA/C/NA/   | dream2-T      | False            | False              | False            | False            |   39.84 |   3.067 |       14 |         -2.051 |      2.11 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |         |          |            |          |  0.25   |       8 |        2 | dream2-T    | inf       |  0.30769 |       2 | right_only |
# |  2 |    11 |        38008306 |      38008306 | GAAGAA | G     | NA/NA/GAAGAA/NA/ | NA/NA/G/NA/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |      45 | 5.85e-16 | 0.82113    |        0 |  0.5    |      34 |        5 | dream2-T    |   0.19025 |  0.00307 |      17 | right_only |
# |  3 |    11 |        62158661 |      62158661 | G      | A,T   | NA/G/NA/NA/      | NA/A,T/NA/NA/ | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |          |         | 3,1    | 0.75,0.25 |      4 |        |         | 1,1     |             |            |      2 |            |          |            |             |         |         |         |         |        |        |        |         |         |     104 | 0        | 1          |        0 |  0.6735 |      49 |        3 | dream2-T    |   0       |  0       |      33 | right_only |
# |  4 |    13 |        25602981 |      25602981 | T      | A     | NA/NA/T/NA/      | NA/NA/A/NA/   | dream2-T      | False            | False              | False            | False            |   52.16 |   0     |        3 |         -2.868 |      3.61 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |         |          |            |          |  0.1818 |      11 |        2 | dream2-T    | inf       |  0.21739 |       2 | right_only |
# |  5 |     3 |       117904072 |     117904072 | T      | A     | NA/T/NA/NA/      | NA/A/NA/NA/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |       60 |      60 | 0.272727 | 7.94546 | 1      | 0.25      |      4 |      3 |       0 | 1       |           1 |            |      2 |          1 |  2.36712 |          1 |         0.8 |       0 |       0 |       0 |       0 |    100 |    314 |     10 |       1 | 3.73412 |         |          |            |          |         |         |          |             |           |          |         | right_only |
# +----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+----------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------+
# Processing 3_180571138
# mutect2
# varscan
# vardict
# freebayes
# missed col: m2_PON
# +----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+----------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------+
# |    |   Chr |   START_POS_REF |   END_POS_REF | REF    | ALT   | REF_MFVdVs       | ALT_MFVdVs    | Sample_Name   | FILTER_Mutect2   | FILTER_Freebayes   | FILTER_Vardict   | FILTER_Varscan   |   m2_MQ |   m2_FS |   m2_MQ0 |   m2_MQRankSum |   m2_NLOD | m2_PON   |   f_MQMR |   f_MQM |     f_AB |   f_ABP | f_AC   | f_AF      |   f_AN |   f_AO |   f_GTI | f_LEN   |   f_MEANALT | f_MIN_DP   |   f_NS |   f_NUMALT |   f_ODDS |   f_PAIRED |   f_PAIREDR |   f_PAO |   f_PQA |   f_PQR |   f_PRO |   f_QA |   f_QR |   f_RO |   f_RPL |   f_RPP |   vs_DP |   vs_GPV |     vs_SPV |   vs_SSC |   vd_AF |   vd_DP |   vd_MSI | vd_SAMPLE   |    vd_SOR |   vd_SSF |   vd_VD | _merge     |
# |----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+----------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------|
# |  0 |    10 |        42511865 |      42511865 | T      | C     | NA/NA/NA/T/      | NA/NA/NA/C/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |      58 | 1        | 0.00016168 |       37 |         |         |          |             |           |          |         | right_only |
# |  1 |    10 |        48003623 |      48003623 | A      | C     | NA/NA/A/NA/      | NA/NA/C/NA/   | dream2-T      | False            | False              | False            | False            |   39.84 |   3.067 |       14 |         -2.051 |      2.11 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |         |          |            |          |  0.25   |       8 |        2 | dream2-T    | inf       |  0.30769 |       2 | right_only |
# |  2 |    11 |        38008306 |      38008306 | GAAGAA | G     | NA/NA/GAAGAA/NA/ | NA/NA/G/NA/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |      45 | 5.85e-16 | 0.82113    |        0 |  0.5    |      34 |        5 | dream2-T    |   0.19025 |  0.00307 |      17 | right_only |
# |  3 |    11 |        62158661 |      62158661 | G      | A,T   | NA/G/NA/NA/      | NA/A,T/NA/NA/ | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |          |         | 3,1    | 0.75,0.25 |      4 |        |         | 1,1     |             |            |      2 |            |          |            |             |         |         |         |         |        |        |        |         |         |     104 | 0        | 1          |        0 |  0.6735 |      49 |        3 | dream2-T    |   0       |  0       |      33 | right_only |
# |  4 |    13 |        25602981 |      25602981 | T      | A     | NA/NA/T/NA/      | NA/NA/A/NA/   | dream2-T      | False            | False              | False            | False            |   52.16 |   0     |        3 |         -2.868 |      3.61 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |         |          |            |          |  0.1818 |      11 |        2 | dream2-T    | inf       |  0.21739 |       2 | right_only |
# |  5 |     3 |       117904072 |     117904072 | T      | A     | NA/T/NA/NA/      | NA/A/NA/NA/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |       60 |      60 | 0.272727 | 7.94546 | 1      | 0.25      |      4 |      3 |       0 | 1       |           1 |            |      2 |          1 |  2.36712 |          1 |         0.8 |       0 |       0 |       0 |       0 |    100 |    314 |     10 |       1 | 3.73412 |         |          |            |          |         |         |          |             |           |          |         | right_only |
# |  6 |     3 |       180571138 |     180571138 | T      | A     | NA/NA/T/NA/      | NA/NA/A/NA/   | dream2-T      | False            | False              | False            | False            |   58.89 |   7.533 |        1 |          0     |      5.42 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |         |         |          |            |          |  0.1053 |      19 |        1 | dream2-T    | inf       |  0.23077 |       2 | right_only |
# +----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+----------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+---------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------+
# Processing 4_73687566
# mutect2
# varscan
# vardict
# freebayes
# missed col: f_MIN_DP
# +----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+----------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+----------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------+
# |    |   Chr |   START_POS_REF |   END_POS_REF | REF    | ALT   | REF_MFVdVs       | ALT_MFVdVs    | Sample_Name   | FILTER_Mutect2   | FILTER_Freebayes   | FILTER_Vardict   | FILTER_Varscan   |   m2_MQ |   m2_FS |   m2_MQ0 |   m2_MQRankSum |   m2_NLOD | m2_PON   |   f_MQMR |   f_MQM |     f_AB |   f_ABP | f_AC   | f_AF      |   f_AN |   f_AO |   f_GTI | f_LEN   |   f_MEANALT | f_MIN_DP   |   f_NS |   f_NUMALT |   f_ODDS |   f_PAIRED |   f_PAIREDR |   f_PAO |   f_PQA |   f_PQR |   f_PRO |   f_QA |   f_QR |   f_RO |   f_RPL |    f_RPP |   vs_DP |   vs_GPV |     vs_SPV |   vs_SSC |   vd_AF |   vd_DP |   vd_MSI | vd_SAMPLE   |    vd_SOR |   vd_SSF |   vd_VD | _merge     |
# |----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+----------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+----------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------|
# |  0 |    10 |        42511865 |      42511865 | T      | C     | NA/NA/NA/T/      | NA/NA/NA/C/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |      58 | 1        | 0.00016168 |       37 |         |         |          |             |           |          |         | right_only |
# |  1 |    10 |        48003623 |      48003623 | A      | C     | NA/NA/A/NA/      | NA/NA/C/NA/   | dream2-T      | False            | False              | False            | False            |   39.84 |   3.067 |       14 |         -2.051 |      2.11 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |         |          |            |          |  0.25   |       8 |        2 | dream2-T    | inf       |  0.30769 |       2 | right_only |
# |  2 |    11 |        38008306 |      38008306 | GAAGAA | G     | NA/NA/GAAGAA/NA/ | NA/NA/G/NA/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |      45 | 5.85e-16 | 0.82113    |        0 |  0.5    |      34 |        5 | dream2-T    |   0.19025 |  0.00307 |      17 | right_only |
# |  3 |    11 |        62158661 |      62158661 | G      | A,T   | NA/G/NA/NA/      | NA/A,T/NA/NA/ | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |          |         | 3,1    | 0.75,0.25 |      4 |        |         | 1,1     |             |            |      2 |            |          |            |             |         |         |         |         |        |        |        |         |          |     104 | 0        | 1          |        0 |  0.6735 |      49 |        3 | dream2-T    |   0       |  0       |      33 | right_only |
# |  4 |    13 |        25602981 |      25602981 | T      | A     | NA/NA/T/NA/      | NA/NA/A/NA/   | dream2-T      | False            | False              | False            | False            |   52.16 |   0     |        3 |         -2.868 |      3.61 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |         |          |            |          |  0.1818 |      11 |        2 | dream2-T    | inf       |  0.21739 |       2 | right_only |
# |  5 |     3 |       117904072 |     117904072 | T      | A     | NA/T/NA/NA/      | NA/A/NA/NA/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |  60      |      60 | 0.272727 | 7.94546 | 1      | 0.25      |      4 |      3 |       0 | 1       |           1 |            |      2 |          1 |  2.36712 |          1 |    0.8      |       0 |       0 |       0 |       0 |    100 |    314 |     10 |       1 |  3.73412 |         |          |            |          |         |         |          |             |           |          |         | right_only |
# |  6 |     3 |       180571138 |     180571138 | T      | A     | NA/NA/T/NA/      | NA/NA/A/NA/   | dream2-T      | False            | False              | False            | False            |   58.89 |   7.533 |        1 |          0     |      5.42 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |         |          |            |          |  0.1053 |      19 |        1 | dream2-T    | inf       |  0.23077 |       2 | right_only |
# |  7 |     4 |        73687566 |      73687566 | T      | G     | NA/T/NA/NA/      | NA/G/NA/NA/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |  58.9091 |      60 | 0.333333 | 5.9056  | 1      | 0.25      |      4 |      4 |       0 | 1       |           1 |            |      2 |          1 |  3.06027 |          1 |    0.727273 |       0 |       0 |       0 |       0 |    132 |    346 |     11 |       4 | 11.6962  |         |          |            |          |         |         |          |             |           |          |         | right_only |
# +----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+----------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+----------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------+
# Processing 5_70178029
# mutect2
# varscan
# vardict
# freebayes
# Processing 6_40168576
# mutect2
# varscan
# vardict
# freebayes
# missed col: m2_PON
# ...
# |  4 |    13 |        25602981 |      25602981 | T      | A     | NA/NA/T/NA/      | NA/NA/A/NA/   | dream2-T      | False            | False              | False            | False            |   52.16 |   0     |        3 |         -2.868 |      3.61 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |         |          |            |          |  0.1818 |      11 |        2 | dream2-T    | inf       |  0.21739 |       2 | right_only |
# |  5 |     3 |       117904072 |     117904072 | T      | A     | NA/T/NA/NA/      | NA/A/NA/NA/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |  60      |      60 | 0.272727 | 7.94546 | 1      | 0.25      |      4 |      3 |       0 | 1       |           1 |            |      2 |          1 |  2.36712 |          1 |    0.8      |       0 |       0 |       0 |       0 |    100 |    314 |     10 |       1 |  3.73412 |         |          |            |          |         |         |          |             |           |          |         | right_only |
# |  6 |     3 |       180571138 |     180571138 | T      | A     | NA/NA/T/NA/      | NA/NA/A/NA/   | dream2-T      | False            | False              | False            | False            |   58.89 |   7.533 |        1 |          0     |      5.42 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |         |          |            |          |  0.1053 |      19 |        1 | dream2-T    | inf       |  0.23077 |       2 | right_only |
# |  7 |     4 |        73687566 |      73687566 | T      | G     | NA/T/NA/NA/      | NA/G/NA/NA/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |  58.9091 |      60 | 0.333333 | 5.9056  | 1      | 0.25      |      4 |      4 |       0 | 1       |           1 |            |      2 |          1 |  3.06027 |          1 |    0.727273 |       0 |       0 |       0 |       0 |    132 |    346 |     11 |       4 | 11.6962  |         |          |            |          |         |         |          |             |           |          |         | right_only |
# |  8 |     6 |        40168576 |      40168576 | A      | T     | A/NA/NA/NA/      | T/NA/NA/NA/   | dream2-T      | False            | False              | False            | False            |   60    |   2.884 |        0 |          0     |     10.53 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |         |          |            |          |         |         |          |             |           |          |         | right_only |
# |  9 |     6 |        50579827 |      50579827 | T      | G     | NA/NA/T/NA/      | NA/NA/G/NA/   | dream2-T      | False            | False              | False            | False            |   60    |   7.419 |        0 |          0     |      9.63 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |         |          |            |          |  0.1053 |      19 |        1 | dream2-T    | inf       |  0.1195  |       2 | right_only |
# +----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+----------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+----------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------+
# Processing 7_74662382
# mutect2
# varscan
# vardict
# freebayes
# Processing 8_67250214
# mutect2
# varscan
# vardict
# freebayes
# missed col: m2_PON
# +----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+----------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+----------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------+
# |    |   Chr |   START_POS_REF |   END_POS_REF | REF    | ALT   | REF_MFVdVs       | ALT_MFVdVs    | Sample_Name   | FILTER_Mutect2   | FILTER_Freebayes   | FILTER_Vardict   | FILTER_Varscan   |   m2_MQ |   m2_FS |   m2_MQ0 |   m2_MQRankSum |   m2_NLOD | m2_PON   |   f_MQMR |   f_MQM |     f_AB |   f_ABP | f_AC   | f_AF      |   f_AN |   f_AO |   f_GTI | f_LEN   |   f_MEANALT | f_MIN_DP   |   f_NS |   f_NUMALT |   f_ODDS |   f_PAIRED |   f_PAIREDR |   f_PAO |   f_PQA |   f_PQR |   f_PRO |   f_QA |   f_QR |   f_RO |   f_RPL |    f_RPP |   vs_DP |   vs_GPV |     vs_SPV |   vs_SSC |   vd_AF |   vd_DP |   vd_MSI | vd_SAMPLE   |    vd_SOR |   vd_SSF |   vd_VD | _merge     |
# |----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+----------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+----------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------|
# |  0 |    10 |        42511865 |      42511865 | T      | C     | NA/NA/NA/T/      | NA/NA/NA/C/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |      58 | 1        | 0.00016168 |       37 |         |         |          |             |           |          |         | right_only |
# |  1 |    10 |        48003623 |      48003623 | A      | C     | NA/NA/A/NA/      | NA/NA/C/NA/   | dream2-T      | False            | False              | False            | False            |   39.84 |   3.067 |       14 |         -2.051 |      2.11 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |         |          |            |          |  0.25   |       8 |        2 | dream2-T    | inf       |  0.30769 |       2 | right_only |
# |  2 |    11 |        38008306 |      38008306 | GAAGAA | G     | NA/NA/GAAGAA/NA/ | NA/NA/G/NA/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |      45 | 5.85e-16 | 0.82113    |        0 |  0.5    |      34 |        5 | dream2-T    |   0.19025 |  0.00307 |      17 | right_only |
# |  3 |    11 |        62158661 |      62158661 | G      | A,T   | NA/G/NA/NA/      | NA/A,T/NA/NA/ | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |          |         |          |         | 3,1    | 0.75,0.25 |      4 |        |         | 1,1     |             |            |      2 |            |          |            |             |         |         |         |         |        |        |        |         |          |     104 | 0        | 1          |        0 |  0.6735 |      49 |        3 | dream2-T    |   0       |  0       |      33 | right_only |
# |  4 |    13 |        25602981 |      25602981 | T      | A     | NA/NA/T/NA/      | NA/NA/A/NA/   | dream2-T      | False            | False              | False            | False            |   52.16 |   0     |        3 |         -2.868 |      3.61 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |         |          |            |          |  0.1818 |      11 |        2 | dream2-T    | inf       |  0.21739 |       2 | right_only |
# |  5 |     3 |       117904072 |     117904072 | T      | A     | NA/T/NA/NA/      | NA/A/NA/NA/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |  60      |      60 | 0.272727 | 7.94546 | 1      | 0.25      |      4 |      3 |       0 | 1       |           1 |            |      2 |          1 |  2.36712 |          1 |    0.8      |       0 |       0 |       0 |       0 |    100 |    314 |     10 |       1 |  3.73412 |         |          |            |          |         |         |          |             |           |          |         | right_only |
# |  6 |     3 |       180571138 |     180571138 | T      | A     | NA/NA/T/NA/      | NA/NA/A/NA/   | dream2-T      | False            | False              | False            | False            |   58.89 |   7.533 |        1 |          0     |      5.42 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |         |          |            |          |  0.1053 |      19 |        1 | dream2-T    | inf       |  0.23077 |       2 | right_only |
# |  7 |     4 |        73687566 |      73687566 | T      | G     | NA/T/NA/NA/      | NA/G/NA/NA/   | dream2-T      | False            | False              | False            | False            |         |         |          |                |           |          |  58.9091 |      60 | 0.333333 | 5.9056  | 1      | 0.25      |      4 |      4 |       0 | 1       |           1 |            |      2 |          1 |  3.06027 |          1 |    0.727273 |       0 |       0 |       0 |       0 |    132 |    346 |     11 |       4 | 11.6962  |         |          |            |          |         |         |          |             |           |          |         | right_only |
# |  8 |     6 |        40168576 |      40168576 | A      | T     | A/NA/NA/NA/      | T/NA/NA/NA/   | dream2-T      | False            | False              | False            | False            |   60    |   2.884 |        0 |          0     |     10.53 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |         |          |            |          |         |         |          |             |           |          |         | right_only |
# |  9 |     6 |        50579827 |      50579827 | T      | G     | NA/NA/T/NA/      | NA/NA/G/NA/   | dream2-T      | False            | False              | False            | False            |   60    |   7.419 |        0 |          0     |      9.63 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |         |          |            |          |  0.1053 |      19 |        1 | dream2-T    | inf       |  0.1195  |       2 | right_only |
# | 10 |     8 |        67250214 |      67250214 | C      | T     | NA/NA/C/NA/      | NA/NA/T/NA/   | dream2-T      | False            | False              | False            | False            |   60    |   2.89  |        0 |          0     |     16.25 |          |          |         |          |         |        |           |        |        |         |         |             |            |        |            |          |            |             |         |         |         |         |        |        |        |         |          |         |          |            |          |  0.125  |      16 |        3 | dream2-T    | inf       |  0.04324 |       2 | right_only |
# +----+-------+-----------------+---------------+--------+-------+------------------+---------------+---------------+------------------+--------------------+------------------+------------------+---------+---------+----------+----------------+-----------+----------+----------+---------+----------+---------+--------+-----------+--------+--------+---------+---------+-------------+------------+--------+------------+----------+------------+-------------+---------+---------+---------+---------+--------+--------+--------+---------+----------+---------+----------+------------+----------+---------+---------+----------+-------------+-----------+----------+---------+------------+
# Processing 9_41439476
# mutect2
# varscan
# vardict
# freebayes
# Processing 9_42835762
# mutect2
# varscan
# vardict
# freebayes
# Processing 9_69371557
# mutect2
# varscan
# vardict
# freebayes
# Processing X_70920198
# mutect2
# varscan
# vardict
# freebayes
# Processing X_72109551
# mutect2
# varscan
# vardict
# freebayes

# %%
df_missed.drop(['_merge'], axis=1, inplace=True)

# %%
df1.shape
# Out:
# (45376, 55)

# %%
df_missed['START_POS_REF'] = df_missed['START_POS_REF'].astype(int)
df_missed['END_POS_REF'] = df_missed['END_POS_REF'].astype(int)
df_missed['Chr'] = df_missed['Chr'].astype(str)

# %%
df_all = pd.concat([df1, df_missed], ignore_index=True)
df_all
# Out:
#       Chr  START_POS_REF  END_POS_REF REF ALT   REF_MFVdVs   ALT_MFVdVs  \
# 0       1         101674       101674   C   A  NA/NA/NA/C/  NA/NA/NA/A/
# 1       1         109534       109534   A   C   NA/NA/A/A/   NA/NA/C/C/
# 2       1         137172       137172   T   G  T/NA/NA/NA/  G/NA/NA/NA/
# 3       1         149875       149875   G   C  NA/NA/NA/G/  NA/NA/NA/C/
# 4       1         149876       149876   C   G  NA/NA/NA/C/  NA/NA/NA/G/
# ...    ..            ...          ...  ..  ..          ...          ...
# 45382   3      180571138    180571138   T   A  NA/NA/T/NA/  NA/NA/A/NA/
# 45383   4       73687566     73687566   T   G  NA/T/NA/NA/  NA/G/NA/NA/
# 45384   6       40168576     40168576   A   T  A/NA/NA/NA/  T/NA/NA/NA/
# 45385   6       50579827     50579827   T   G  NA/NA/T/NA/  NA/NA/G/NA/
# 45386   8       67250214     67250214   C   T  NA/NA/C/NA/  NA/NA/T/NA/
#
#       Sample_Name FILTER_Mutect2 FILTER_Freebayes  ...    vs_GPV    vs_SPV  \
# 0        dream2-T          False            False  ...       1.0  0.037328
# 1        dream2-T          False            False  ...  0.006298   0.22116
# 2        dream2-T           True            False  ...       NaN       NaN
# 3        dream2-T          False            False  ...       1.0   0.43333
# 4        dream2-T          False            False  ...       1.0   0.43333
# ...           ...            ...              ...  ...       ...       ...
# 45382    dream2-T          False            False  ...      None      None
# 45383    dream2-T          False            False  ...      None      None
# 45384    dream2-T          False            False  ...      None      None
# 45385    dream2-T          False            False  ...      None      None
# 45386    dream2-T          False            False  ...      None      None
#
#       vs_SSC   vd_AF vd_DP vd_MSI vd_SAMPLE vd_SOR   vd_SSF vd_VD
# 0       14.0     NaN   NaN    NaN       NaN    NaN      NaN   NaN
# 1        6.0  0.1765  17.0    2.0       NaN    inf  0.26154   3.0
# 2        NaN     NaN   NaN    NaN       NaN    NaN      NaN   NaN
# 3        3.0     NaN   NaN    NaN       NaN    NaN      NaN   NaN
# 4        3.0     NaN   NaN    NaN       NaN    NaN      NaN   NaN
# ...      ...     ...   ...    ...       ...    ...      ...   ...
# 45382   None  0.1053    19      1  dream2-T    inf  0.23077     2
# 45383   None    None  None   None      None   None     None  None
# 45384   None    None  None   None      None   None     None  None
# 45385   None  0.1053    19      1  dream2-T    inf   0.1195     2
# 45386   None   0.125    16      3  dream2-T    inf  0.04324     2
#
# [45387 rows x 55 columns]

# %%
df_all_joined = df_all.merge(df_label, on=['Chr', 'START_POS_REF', 'END_POS_REF'], how='outer', indicator=True)
df_all_joined['_merge'].unique()
# Out:
# ['left_only', 'both', 'right_only']
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
df_all_joined['is_snv'] = np.where((df_all_joined['_merge'] == 'both'), True, False)
df_all_joined
# Out:
#       Chr  START_POS_REF  END_POS_REF REF ALT   REF_MFVdVs   ALT_MFVdVs  \
# 0       1         101674       101674   C   A  NA/NA/NA/C/  NA/NA/NA/A/
# 1       1         109534       109534   A   C   NA/NA/A/A/   NA/NA/C/C/
# 2       1         137172       137172   T   G  T/NA/NA/NA/  G/NA/NA/NA/
# 3       1         149875       149875   G   C  NA/NA/NA/G/  NA/NA/NA/C/
# 4       1         149876       149876   C   G  NA/NA/NA/C/  NA/NA/NA/G/
# ...    ..            ...          ...  ..  ..          ...          ...
# 45400   Y       59027438     59027438   G   T  NA/NA/NA/G/  NA/NA/NA/T/
# 45401   Y       59027721     59027721   C   A  C/NA/NA/NA/  A/NA/NA/NA/
# 45402   Y       59028997     59028997   A   G  A/NA/NA/NA/  G/NA/NA/NA/
# 45403   Y       59031582     59031582   G   A  G/NA/NA/NA/  A/NA/NA/NA/
# 45404   Y       59032399     59032399   A   G  A/NA/NA/NA/  G/NA/NA/NA/
#
#       Sample_Name FILTER_Mutect2 FILTER_Freebayes  ... vs_SSC   vd_AF vd_DP  \
# 0        dream2-T          False            False  ...   14.0     NaN   NaN
# 1        dream2-T          False            False  ...    6.0  0.1765  17.0
# 2        dream2-T           True            False  ...    NaN     NaN   NaN
# 3        dream2-T          False            False  ...    3.0     NaN   NaN
# 4        dream2-T          False            False  ...    3.0     NaN   NaN
# ...           ...            ...              ...  ...    ...     ...   ...
# 45400    dream2-T          False            False  ...    7.0     NaN   NaN
# 45401    dream2-T           True            False  ...    NaN     NaN   NaN
# 45402    dream2-T           True            False  ...    NaN     NaN   NaN
# 45403    dream2-T           True            False  ...    NaN     NaN   NaN
# 45404    dream2-T           True            False  ...    NaN     NaN   NaN
#
#       vd_MSI vd_SAMPLE vd_SOR   vd_SSF vd_VD     _merge is_snv
# 0        NaN       NaN    NaN      NaN   NaN  left_only  False
# 1        2.0       NaN    inf  0.26154   3.0  left_only  False
# 2        NaN       NaN    NaN      NaN   NaN  left_only  False
# 3        NaN       NaN    NaN      NaN   NaN  left_only  False
# 4        NaN       NaN    NaN      NaN   NaN  left_only  False
# ...      ...       ...    ...      ...   ...        ...    ...
# 45400    NaN       NaN    NaN      NaN   NaN  left_only  False
# 45401    NaN       NaN    NaN      NaN   NaN  left_only  False
# 45402    NaN       NaN    NaN      NaN   NaN  left_only  False
# 45403    NaN       NaN    NaN      NaN   NaN  left_only  False
# 45404    NaN       NaN    NaN      NaN   NaN  left_only  False
#
# [45405 rows x 57 columns]

# %%
df_all_joined.drop(['_merge'], axis=1, inplace=True)

# %%
df_all_joined.to_csv(f'{curr_folder}_final.csv', sep='\t', index=False)

# %%
curr_folder
# Out:
# 'syn2'

# %%
pwd
# Out:
# '/Users/eugenegan/Documents/cs4220_projects'

# %%
df_all_joined.isnull().sum()
# Out:
# Chr                     0
# START_POS_REF           0
# END_POS_REF             0
# REF                    18
# ALT                    18
# REF_MFVdVs             18
# ALT_MFVdVs             18
# Sample_Name            18
# FILTER_Mutect2         18
# FILTER_Freebayes       18
# FILTER_Vardict         18
# FILTER_Varscan         18
# m2_MQ               30678
# m2_FS               30678
# m2_MQ0              30678
# m2_MQRankSum        30679
# m2_NLOD             30678
# m2_PON              45405
# f_MQMR              34262
# f_MQM               34262
# f_AB                34262
# f_ABP               34262
# f_AC                28030
# f_AF                28030
# f_AN                28030
# f_AO                34262
# f_GTI               34262
# f_LEN               28030
# f_MEANALT           34262
# f_MIN_DP            45405
# f_NS                28030
# f_NUMALT            34262
# f_ODDS              34262
# f_PAIRED            34262
# f_PAIREDR           34262
# f_PAO               34262
# f_PQA               34262
# f_PQR               34262
# f_PRO               34262
# f_QA                34262
# f_QR                34262
# f_RO                34262
# f_RPL               34262
# f_RPP               34262
# vs_DP               12993
# vs_GPV              12993
# vs_SPV              12993
# vs_SSC              12993
# vd_AF               26768
# vd_DP               26768
# vd_MSI              26768
# vd_SAMPLE           45398
# vd_SOR              26768
# vd_SSF              26768
# vd_VD               26768
# is_snv                  0
# dtype: int64

# %%
df_all_joined.describe(include='all')
# Out:
#           Chr  START_POS_REF   END_POS_REF    REF    ALT   REF_MFVdVs  \
# count   45405   4.540500e+04  4.540500e+04  45387  45387        45387
# unique     73            NaN           NaN      5      5           61
# top         1            NaN           NaN      G      A  NA/NA/NA/G/
# freq     3548            NaN           NaN  11883  12510         4442
# mean      NaN   7.065027e+07  7.065027e+07    NaN    NaN          NaN
# std       NaN   5.623689e+07  5.623689e+07    NaN    NaN          NaN
# min       NaN   3.000000e+00  3.000000e+00    NaN    NaN          NaN
# 25%       NaN   2.482153e+07  2.482153e+07    NaN    NaN          NaN
# 50%       NaN   5.864698e+07  5.864698e+07    NaN    NaN          NaN
# 75%       NaN   1.066267e+08  1.066267e+08    NaN    NaN          NaN
# max       NaN   2.492396e+08  2.492396e+08    NaN    NaN          NaN
#
#          ALT_MFVdVs Sample_Name FILTER_Mutect2 FILTER_Freebayes  ...   vs_SPV  \
# count         45387       45387          45387            45387  ...  32412.0
# unique          567           1              2                2  ...  13730.0
# top     NA/NA/NA/A/    dream2-T          False            False  ...      1.0
# freq           4772       45387          33088            36308  ...    313.0
# mean            NaN         NaN            NaN              NaN  ...      NaN
# std             NaN         NaN            NaN              NaN  ...      NaN
# min             NaN         NaN            NaN              NaN  ...      NaN
# 25%             NaN         NaN            NaN              NaN  ...      NaN
# 50%             NaN         NaN            NaN              NaN  ...      NaN
# 75%             NaN         NaN            NaN              NaN  ...      NaN
# max             NaN         NaN            NaN              NaN  ...      NaN
#
#          vs_SSC       vd_AF    vd_DP   vd_MSI  vd_SAMPLE   vd_SOR   vd_SSF  \
# count   32412.0  18637.0000  18637.0  18637.0          7  18637.0  18637.0
# unique    110.0   1534.0000    359.0     48.0          1   5316.0   7013.0
# top         6.0      0.3333     20.0      1.0   dream2-T      inf      0.0
# freq     3244.0    756.0000    498.0   5959.0          7  12802.0   2706.0
# mean        NaN         NaN      NaN      NaN        NaN      NaN      NaN
# std         NaN         NaN      NaN      NaN        NaN      NaN      NaN
# min         NaN         NaN      NaN      NaN        NaN      NaN      NaN
# 25%         NaN         NaN      NaN      NaN        NaN      NaN      NaN
# 50%         NaN         NaN      NaN      NaN        NaN      NaN      NaN
# 75%         NaN         NaN      NaN      NaN        NaN      NaN      NaN
# max         NaN         NaN      NaN      NaN        NaN      NaN      NaN
#
#           vd_VD  is_snv
# count   18637.0   45405
# unique    126.0       2
# top         6.0   False
# freq     1574.0   41091
# mean        NaN     NaN
# std         NaN     NaN
# min         NaN     NaN
# 25%         NaN     NaN
# 50%         NaN     NaN
# 75%         NaN     NaN
# max         NaN     NaN
#
# [11 rows x 56 columns]

# %%
df_all_joined[df_all_joined['is_snv']==True]
# Out:
#       Chr  START_POS_REF  END_POS_REF REF ALT REF_MFVdVs ALT_MFVdVs  \
# 72      1        1787808      1787808   C   T   C/C/C/C/   T/T/T/T/
# 73      1        1819379      1819379   A   C  A/A/NA/A/  C/C/NA/C/
# 79      1        2115269      2115269   A   T   A/A/A/A/   T/T/T/T/
# 98      1        2422541      2422541   G   C   G/G/G/G/   C/C/C/C/
# 100     1        2494323      2494323   C   T   C/C/C/C/   T/T/T/T/
# ...    ..            ...          ...  ..  ..        ...        ...
# 44463   X      153631641    153631641   A   T   A/A/A/A/   T/T/T/T/
# 44466   X      154104082    154104082   A   T   A/A/A/A/   T/T/T/T/
# 44467   X      154417237    154417237   A   C   A/A/A/A/   C/C/C/C/
# 44472   X      154795622    154795622   G   C   G/G/G/G/   C/C/C/C/
# 44476   X      155068256    155068256   A   T   A/A/A/A/   T/T/T/T/
#
#       Sample_Name FILTER_Mutect2 FILTER_Freebayes  ...    vs_SPV vs_SSC  \
# 72       dream2-T           True             True  ...  0.000021   46.0
# 73       dream2-T           True            False  ...  0.002339   26.0
# 79       dream2-T           True             True  ...  0.000085   40.0
# 98       dream2-T           True             True  ...       0.0   67.0
# 100      dream2-T           True             True  ...  0.000005   52.0
# ...           ...            ...              ...  ...       ...    ...
# 44463    dream2-T           True             True  ...       0.0   77.0
# 44466    dream2-T           True             True  ...  0.010021   19.0
# 44467    dream2-T           True             True  ...       0.0   65.0
# 44472    dream2-T           True             True  ...  0.000005   52.0
# 44476    dream2-T           True             True  ...   0.00137   28.0
#
#         vd_AF vd_DP vd_MSI vd_SAMPLE vd_SOR   vd_SSF vd_VD is_snv
# 72     0.3051  59.0    3.0       NaN    inf  0.00001  18.0   True
# 73        NaN   NaN    NaN       NaN    NaN      NaN   NaN   True
# 79     0.3158  38.0    2.0       NaN    inf  0.00001  12.0   True
# 98     0.3188  69.0    3.0       NaN    inf      0.0  22.0   True
# 100    0.3061  49.0    1.0       NaN    inf      0.0  15.0   True
# ...       ...   ...    ...       ...    ...      ...   ...    ...
# 44463  0.2941  68.0    3.0       NaN    inf      0.0  20.0   True
# 44466  0.2308  26.0    1.0       NaN    inf  0.00709   6.0   True
# 44467  0.3333  42.0    2.0       NaN    inf      0.0  14.0   True
# 44472  0.3208  53.0    1.0       NaN    inf      0.0  17.0   True
# 44476  0.2941  34.0    1.0       NaN    inf  0.00028  10.0   True
#
# [4314 rows x 56 columns]
